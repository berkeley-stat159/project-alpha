# %%
# Import modules.
from __future__ import (absolute_import,
                        division,
                        print_function,
                        unicode_literals)
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import nibabel as nib
from stimuli import events2neural

# %%
# Load BART 4-D data.
path = "/home/oski/s159/project-alpha/ds009/sub013"
img = nib.load(path+"/BOLD/task001_run001/bold.nii.gz")
data = img.get_data()
data.shape
# Out:
# (64, 64, 34, 249)

# %%
# Plot center slice of first volume.
plt.imshow(data[:, :, 16, 0], cmap='gray')

# %%
# Plot center slice of last volume.
plt.imshow(data[:, :, 16, 248], cmap='gray')

# %%
# Plot center slice of some volume in the middle.
plt.imshow(data[:, :, 16, 120], cmap='gray')

# %%
# variance across the final (time) axis
var_vol = np.var(data, axis=3)
plt.imshow(var_vol[:, :, 16], cmap='gray')

# %%
# Get standard deviation for each volume; then plot the values
# Seems to rise over time. Maybe want to get rid of the first few values 
# and possibly the last few. 
stds = []
for i in range(data.shape[-1]):
    vol = data[..., i]
    stds.append(np.std(vol))
plt.plot(stds)

# %%
# Unclear to me how to handle multiple condition files. 
# Will investigate.
